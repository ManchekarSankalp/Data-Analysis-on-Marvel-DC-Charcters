# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
marvel=pd.read_csv('charcters_stats.csv')
marvel
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 4        Abomination       bad            63        80     53          90
# ..               ...       ...           ...       ...    ...         ...
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
# 610             Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 0       25      52    233
# ...

# %%
marvel.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %%
marvel.tail()
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
# 610             Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 606     12      14    164
# 607     31      28    182
# 608     83      28    388
# 609    100      56    292
# 610     72      28    288

# %%
marvel.shape
# Out:
# (611, 9)

# %%
marvel['Alignment'].value_counts()
# Out:
# good       432
# bad        165
# neutral     11
# Name: Alignment, dtype: int64

# %%
good=marvel[marvel['Alignment']=="good"]

# %%
good.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 6  Adam Monroe      good            63        10     12         100     71
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 6      64    320

# %%
good.tail()
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 604            X-Man      good            88        53     53          95
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
#
#      Power  Combat  Total
# 604     92      84    465
# 606     12      14    164
# 607     31      28    182
# 608     83      28    388
# 609    100      56    292

# %%
good
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 6        Adam Monroe      good            63        10     12         100
# ..               ...       ...           ...       ...    ...         ...
# 604            X-Man      good            88        53     53          95
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
#
#      Power  Combat  Total
# 0       25      52    233
# ...

# %%
good.sort_values(by=['Speed'],ascending=False).head()
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 231       Flash III      good            63        10    100          60
# 304  Jack of Hearts      good            63        55    100          30
# 295         Impulse      good            50        10    100          60
# 525        Stardust      good            88        85    100         110
# 447     Quicksilver      good            63        28    100          60
#
#      Power  Combat  Total
# 231     83      32    348
# 304     70      30    348
# 295     63      60    343
# 525    100      85    568
# 447     57      56    364

# %% [markdown]
# good_max_speed=good[good['Speed']==100]

# %%
good_max_speed=good[good['Speed']==100]

# %%
good_min_speed=good[good['Speed']==1]
good_min_speed
# Out:
#                  Name Alignment  Intelligence  Strength  Speed  Durability  \
# 7        Adam Strange      good             1         1      1           1
# 8           Agent  13      good             1         1      1           1
# 13       Alex Woolsly      good             1         1      1           1
# 15   Allan Quatermain      good             1         1      1           1
# 18     Ando Masahashi      good             1         1      1           1
# ..                ...       ...           ...       ...    ...         ...
# 580            Vulcan      good             1         1      1           1
# 584           Warbird      good             1         1      1           1
# 591       White Queen      good             1         1      1           1
# 595           Wiz Kid      good             1         1      1           1
# 601            Wondra      good             1         1      1           1
#
#      Power  Combat  Total
# 7        0       1      5
# ...

# %%
good.sort_values(by=['Power'],ascending=False).head()
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 609        Zatanna      good            75        10     23          28
# 546           Thor      good            69       100     92         100
# 511          Spawn      good            75        60     50          90
# 69   Beta Ray Bill      good            63        80     35          95
# 70        Beyonder      good            88       100     23         100
#
#      Power  Combat  Total
# 609    100      56    292
# 546    100      85    546
# 511    100      95    470
# 69     100      84    457
# 70     100      56    467

# %%
good_max_power=good.sort_values(by=['Power'],ascending=False)
good_max_power.head()
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 609        Zatanna      good            75        10     23          28
# 546           Thor      good            69       100     92         100
# 511          Spawn      good            75        60     50          90
# 69   Beta Ray Bill      good            63        80     35          95
# 70        Beyonder      good            88       100     23         100
#
#      Power  Combat  Total
# 609    100      56    292
# 546    100      85    546
# 511    100      95    470
# 69     100      84    457
# 70     100      56    467

# %%
good_max_speed
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 85       Black Bolt      good            75        67    100          84
# 229         Flash I      good            63        10    100          50
# 230        Flash II      good            63        10    100          60
# 231       Flash III      good            63        10    100          60
# 232        Flash IV      good            63        10    100          32
# 295         Impulse      good            50        10    100          60
# 304  Jack of Hearts      good            63        55    100          30
# 333          Krypto      good             9        80    100          90
# 418            Nova      good            38        60    100         100
# 447     Quicksilver      good            63        28    100          60
# 525        Stardust      good            88        85    100         110
# 537        Superman      good           100       100    100         100
#
# ...

# %%
good_min_power=good.sort_values(by=['Power'],ascending=True)
good_min_power.head()
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 255         Goliath IV      good             1         1      1           1
# 573         Vertigo II      good             1         1      1           1
# 228       Flash Gordon      good             1         1      1           1
# 568           Valkyrie      good             1         1      1           1
# 234  Franklin Richards      good             1         1      1           1
#
#      Power  Combat  Total
# 255      0       1      5
# 573      0       1      5
# 228      0       1      5
# 568      0       1      5
# 234      0       1      5

# %%
plt.figure(figsize=(8,5))
plt.bar(list(good_max_power['Name'])[0:5],list(good_max_power['Total'])[0:5],color='Blue')
plt.show()

# %%
bad=marvel[marvel['Alignment']=='bad']
bad
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 4       Abomination       bad            63        80     53          90
# 5           Abraxas       bad            88       100     83          99
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 17             Ammo       bad             1         1      1           1
# ..              ...       ...           ...       ...    ...         ...
# 586            Warp       bad            38        10     23          28
# 590       Weapon XI       bad             1         1      1           1
# 593  Willis Stryker       bad            38        16     23          28
# 605     Yellow Claw       bad             1         1      1           1
# 610            Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 4       55      95    436
# 5      100      56    526
# ...

# %%
bad.head()
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 4   Abomination       bad            63        80     53          90     55
# 5       Abraxas       bad            88       100     83          99    100
# 11   Air-Walker       bad            50        85    100          85    100
# 16        Amazo       bad            75       100    100         100    100
# 17         Ammo       bad             1         1      1           1      0
#
#     Combat  Total
# 4       95    436
# 5       56    526
# 11      40    460
# 16     100    575
# 17       1      5

# %%
bad.sort_values(by=['Speed'],ascending=False).head()
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 610            Zoom       bad            50        10    100          28
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 535  Superboy-Prime       bad            94       100    100         100
# 242     General Zod       bad            94       100     96         100
#
#      Power  Combat  Total
# 610     72      28    288
# 11     100      40    460
# 16     100     100    575
# 535    100      85    579
# 242     94      95    579

# %%
bad.sort_values(by=['Speed'],ascending=True).head()
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 254      Goliath III       bad             1         1      1           1
# 115       Bomb Queen       bad             1         1      1           1
# 515   Spider-Carnage       bad             1         1      1           1
# 521  Spider-Woman IV       bad             1         1      1           1
# 349    Luke Campbell       bad             1         1      1           1
#
#      Power  Combat  Total
# 254      0       1      5
# 115      0       1      5
# 515      0       1      5
# 521      0       1      5
# 349      0       1      5

# %%
bad.sort_values(by=['Intelligence'],ascending=False).head()
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 386  Mister Mxyzptlk       bad           113        10     12          14
# 338       Lex Luthor       bad           100        10     12          14
# 336           Leader       bad           100        10     12          14
# 122         Brainiac       bad           100        28     63          90
# 194      Doctor Doom       bad           100        32     20         100
#
#      Power  Combat  Total
# 386    100      28    277
# 338     10      28    174
# 336     58      42    236
# 122     60      75    416
# 194     93      84    429

# %%
bad.sort_values(by=['Total'],ascending=True).head()
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 349  Luke Campbell       bad             1         1      1           1
# 115     Bomb Queen       bad             1         1      1           1
# 216  Fabian Cortez       bad             1         1      1           1
# 390         Moloch       bad             1         1      1           1
# 309         Jigsaw       bad             1         1      1           1
#
#      Power  Combat  Total
# 349      0       1      5
# 115      0       1      5
# 216      0       1      5
# 390      0       1      5
# 309      0       1      5

# %%
bad.sort_values(by=['Total'],ascending=False).head()
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 535  Superboy-Prime       bad            94       100    100         100
# 242     General Zod       bad            94       100     96         100
# 16            Amazo       bad            75       100    100         100
# 203        Dormammu       bad            88        95     83         100
# 201        Doomsday       bad            88        80     67         120
#
#      Power  Combat  Total
# 535    100      85    579
# 242     94      95    579
# 16     100     100    575
# 203    100      80    546
# 201    100      90    545

# %%
bad_max_power=bad.sort_values(by=['Power'],ascending=False)

# %%
bad_max_power.head()
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 564           Ultron       bad            88        83     42         100
# 422        Onslaught       bad            88        85     47         100
# 180         Darkseid       bad            88       100     23         100
# 501         Sinestro       bad            75        80     53          64
# 386  Mister Mxyzptlk       bad           113        10     12          14
#
#      Power  Combat  Total
# 564    100      64    477
# 422    100      85    505
# 180    100      95    506
# 501    100      56    428
# 386    100      28    277

# %%
bad_min_power=bad.sort_values(by=['Power'],ascending=True)

# %%
bad_min_power.head()
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 349    Luke Campbell       bad             1         1      1           1
# 521  Spider-Woman IV       bad             1         1      1           1
# 515   Spider-Carnage       bad             1         1      1           1
# 256  Granny Goodness       bad             1         1      1           1
# 605      Yellow Claw       bad             1         1      1           1
#
#      Power  Combat  Total
# 349      0       1      5
# 521      0       1      5
# 515      0       1      5
# 256      0       1      5
# 605      0       1      5

# %%
plt.figure(figsize=(10,5))
plt.bar(list(bad_max_power['Name'])[0:5],list(good_max_power['Total'])[0:5],color=['red','green','blue','black','pink'])
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.hist(good['Speed'])
plt.title("Distribution of speed")
plt.xlabel("Speed")
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.hist(bad['Combat'])
plt.title("Distribution of combat")
plt.xlabel("Combat")
plt.show()

# %%
marvel_1=marvel[['Name','Total']]
marvel_1
# Out:
#                 Name  Total
# 0            3-D Man    233
# 1             A-Bomb    316
# 2         Abe Sapien    299
# 3           Abin Sur    406
# 4        Abomination    436
# ..               ...    ...
# 606     Yellowjacket    164
# 607  Yellowjacket II    182
# 608             Ymir    388
# 609          Zatanna    292
# 610             Zoom    288
#
# [611 rows x 2 columns]

# %%
marvel_1.head()
# Out:
#           Name  Total
# 0      3-D Man    233
# 1       A-Bomb    316
# 2   Abe Sapien    299
# 3     Abin Sur    406
# 4  Abomination    436

# %%
marvel_1.shape
# Out:
# (611, 2)
